# %% [markdown]
# Viendo la documentación de keras, encontré que hay una capa personalizada de polinomios. Por lo que la usaremos

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer

class PolynomialLayer(Layer):
    def __init__(self, **kwargs):
        super(PolynomialLayer, self).__init__(**kwargs)
        self.a = tf.Variable(initial_value = tf.random.normal(shape=(4,)), trainable=True)
    def call(self, inputs):
        x = inputs
        return self.a[0] + self.a[1]*x + self.a[2]*x**2 + self.a[3]*x**3

# %%
import numpy as np 
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

x_train = np.linspace(-1, 1, 100)
y_train = np.cos(2 * x_train)

model = Sequential([PolynomialLayer(input_shape=(1,))])
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 0s 4ms/step - loss: 3.4426
# Epoch 2/50
# 4/4 [==============================] - 0s 4ms/step - loss: 3.2262
# Epoch 3/50
# 4/4 [==============================] - 0s 5ms/step - loss: 3.0244
# Epoch 4/50
# 4/4 [==============================] - 0s 0s/step - loss: 2.8300
# Epoch 5/50
# 4/4 [==============================] - 0s 0s/step - loss: 2.6485
# Epoch 6/50
# 4/4 [==============================] - 0s 0s/step - loss: 2.4644
# Epoch 7/50
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3029
# Epoch 8/50
# 4/4 [==============================] - 0s 0s/step - loss: 2.1483
# Epoch 9/50
# 4/4 [==============================] - 0s 0s/step - loss: 2.0022
# Epoch 10/50
# 4/4 [==============================] - 0s 6ms/step - loss: 1.8580
# Epoch 11/50
# 4/4 [==============================] - 0s 6ms/step - loss: 1.7275
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5999
# Epoch 13/50
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4786
# Epoch 14/50
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3675
# Epoch 15/50
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2542
# Epoch 16/50
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1590
# Epoch 17/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0642
# Epoch 18/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.9775
# Epoch 19/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.9003
# Epoch 20/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.8242
# Epoch 21/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.7519
# Epoch 22/50
# 4/4 [==============================] - 0s 314us/step - loss: 0.6870
# Epoch 23/50
# 4/4 [==============================] - 0s 670us/step - loss: 0.6278
# Epoch 24/50
# 4/4 [==============================] - 0s 393us/step - loss: 0.5712
# Epoch 25/50
# 4/4 [==============================] - 0s 840us/step - loss: 0.5205
# Epoch 26/50
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4743
# Epoch 27/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4295
# Epoch 28/50
# 4/4 [==============================] - 0s 705us/step - loss: 0.3903
# Epoch 29/50
# 4/4 [==============================] - 0s 220us/step - loss: 0.3527
# Epoch 30/50
# 4/4 [==============================] - 0s 957us/step - loss: 0.3182
# Epoch 31/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2878
# Epoch 32/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2586
# Epoch 33/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2341
# Epoch 34/50
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2118
# Epoch 35/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1910
# Epoch 36/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.1712
# Epoch 37/50
# 4/4 [==============================] - 0s 611us/step - loss: 0.1543
# Epoch 38/50
# 4/4 [==============================] - 0s 351us/step - loss: 0.1379
# Epoch 39/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.1231
# Epoch 40/50
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1097
# Epoch 41/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0972
# Epoch 42/50
# 4/4 [==============================] - 0s 801us/step - loss: 0.0866
# Epoch 43/50
# 4/4 [==============================] - 0s 935us/step - loss: 0.0770
# Epoch 44/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0682
# Epoch 45/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.0610
# Epoch 46/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.0541
# Epoch 47/50
# 4/4 [==============================] - 0s 452us/step - loss: 0.0484
# Epoch 48/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.0434
# Epoch 49/50
# 4/4 [==============================] - 0s 514us/step - loss: 0.0386
# Epoch 50/50
# 4/4 [==============================] - 0s 0s/step - loss: 0.0345

# %%
import matplotlib.pyplot as plt

y_pred = model.predict(x_train)
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(x_train, y_train, label='exac')
plt.plot(x_train, y_pred, label='aprox')
plt.title('3sin(pi*x)')
plt.legend()
# Out:
# 4/4 [==============================] - 0s 0s/step
